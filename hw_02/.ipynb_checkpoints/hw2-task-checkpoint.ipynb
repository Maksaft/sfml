# %% [markdown]
# # SkillFactory
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('data/otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не видим)

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 52)

# %%
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 52)

# %%
df_train.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#              ...             REG_PHONE_FL GEN_PHONE_FL LOAN_NUM_TOTAL  \
# 0            ...                        0            1              1
# 1            ...                        0            1              1
# 2            ...                        0            1              2
# 3            ...                        1            1              1
# 4            ...                        0            1              2
#
#   LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT  \
# 0               1             6            2            1              1580
# 1               1             6            1            1              4020
# 2               1            11            0            0                 0
# 3               1             6            3            1  1589,92333333333
# 4               1            16            2            1           1152,15
#
#   LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0             1580                        NaN
# 1             4020                        NaN
# 2                0                        NaN
# 3             1590                        NaN
# 4             2230                        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df_train.columns: # перебираем все столбцы
    if str(df_train[i].dtype) == 'object': # если тип столбца - object
        print('='*10)
        print(i) # выводим название столбца
        print(set(df_train[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n') # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Ученая степень', 'Неполное среднее', 'Высшее', 'Среднее', 'Среднее специальное', 'Два и более высших образования', 'Неоконченное высшее'}
#
#
# ==========
# MARITAL_STATUS
# {'Разведен(а)', 'Гражданский брак', 'Не состоял в браке', 'Состою в браке', 'Вдовец/Вдова'}
#
#
# ==========
# GEN_INDUSTRY
# {nan, 'Развлечения/Искусство', 'Государственная служба', 'Сборочные производства', 'Химия/Парфюмерия/Фармацевтика', 'Салоны красоты и здоровья', 'ЧОП/Детективная д-ть', 'Туризм', 'Другие сферы', 'Информационные услуги', 'Наука', 'Управляющая компания', 'Банк/Финансы', 'Сельское хозяйство', 'Здравоохранение', 'Образование', 'Логистика', 'Недвижимость', 'Транспорт', 'Маркетинг', 'Энергетика', 'Юридические услуги/нотариальные услуги', 'Подбор персонала', 'Страхование', 'Строительство', 'Металлургия/Промышленность/Машиностроение', 'Торговля', 'Коммунальное хоз-во/Дорожные службы', 'Информационные технологии', 'Нефтегазовая промышленность', 'СМИ/Реклама/PR-агенства', 'Ресторанный бизнес/Общественное питание'}
#
#
# ==========
# GEN_TITLE
# {nan, 'Специалист', 'Руководитель высшего звена', 'Партнер', 'Индивидуальный предприниматель', 'Другое', 'Служащий', 'Высококвалифиц. специалист', 'Руководитель низшего звена', 'Руководитель среднего звена', 'Военнослужащий по контракту', 'Рабочий', 'Работник сферы услуг'}
#
#
# ==========
# ORG_TP_STATE
# {'Частная компания', nan, 'Индивидуальный предприниматель', 'Частная ком. с инос. капиталом', 'Некоммерческая организация', 'Государственная комп./учреж.'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {nan, 'С участием', 'Без участия'}
#
#
# ==========
# JOB_DIR
# {nan, 'Кадровая служба и секретариат', 'Бухгалтерия, финансы, планир.', 'Адм-хоз. и трансп. службы', 'Служба безопасности', 'Участие в основ. деятельности', 'Реклама и маркетинг', 'Вспомогательный техперсонал', 'Юридическая служба', 'Снабжение и сбыт', 'Пр-техн. обесп. и телеком.'}
#
#
# ==========
# FAMILY_INCOME
# {'свыше 50000 руб.', 'от 5000 до 10000 руб.', 'от 10000 до 20000 руб.', 'до 5000 руб.', 'от 20000 до 50000 руб.'}
#
#
# ==========
# PERSONAL_INCOME
# {'250000', '16800', '2000', '9340', '15200', '10200', '15000', '51000', '3800', '4340', '55000', '14300', '12600', '7000', '3000', '4300', '41900', '34000', '37000', '80000', '8000', '16100', '13160', '11200', '12500', '9628', '6400', '9800', '24', '5339', '20000', '6600', '6800', '6180', '44000', '19300', '7050', '65000', '3400', '5088', '5680', '15380', '6200', '9400', '11700', '14358', '75000', '8300', '9900', '7800', '33000', '56000', '160000', '17800', '13700', '4590', '17700', '12900', '5100', '11300', '19700', '16700', '28000', '52000', '8800', '4900', '5050', '5790', '16900', '20646,16', '30000', '10000', '4330', '12300', '6300', '7640', '10100', '23100', '67000', '10400', '70000', '100000', '40000', '9500', '10500', '7500', '5230', '7600', '7400', '25000', '3200', '13150', '6670', '46000', '16000', '12800', '170000', '12700', '43000', '110000', '8726', '17200', '54000', '4360', '4400', '27300', '9600', '13200', '19800', '4700', '5582', '68000', '7220', '15300', '9300', '14000', '6359', '6900', '5360', '45000', '26500', '13400', '8066', '13300', '25800', '7700', '10700', '9240', '12400', '16050', '1950', '16500', '27000', '11640', '29500', '20500', '92000', '3500', '17500', '17404', '50000', '6700', '14700', '31000', '11000', '6500', '8100', '3900', '17600', '7650', '7900', '41000', '15500', '8500', '32000', '11400', '32640', '19600', '6299,19', '13500', '13450', '67700', '21000', '9000', '5600', '7850', '17900', '7550', '24000', '11800', '6100', '8250', '38000', '8600', '3100', '4500', '5200', '29000', '26000', '4200', '11900', '14800', '28300', '15560', '22500', '24800', '5700', '22955', '19500', '60000', '9200', '12000', '16200', '8900', '2100', '18000', '4000', '13000', '5500', '11500', '10300', '39000', '9100', '4600', '53000', '24500', '18700', '18500', '5800', '36000', '3700', '10800', '19000', '29800', '12100', '4515', '23800', '4100', '8400', '9700', '7250', '2800', '21800', '5300', '23000', '15400', '5446', '150000', '8700', '23500', '13800', '5460', '6000', '7101', '42000', '5900', '4800', '5000', '220000', '6608', '17000', '13900', '7200', '3300', '18200', '15600', '8350', '35000', '10600', '47000', '12650', '7100', '22000', '18600', '21500', '77000', '8200', '4950', '49000', '42500', '13600', '10900', '7300', '5350', '7251', '5425', '3600', '48000', '2300', '9330', '5400', '14500', '11600', '7830'}
#
#
# ==========
# REG_ADDRESS_PROVINCE
# {'Ханты-Мансийский АО', 'Брянская область', 'Татарстан', 'Мордовская республика', 'Волгоградская область', 'Ростовская область', 'Калмыкия', 'Калининградская область', 'Вологодская область', 'Астраханская область', 'Хакасия', 'Пензенская область', 'Алтайский край', 'Курганская область', 'Марийская республика', 'Новосибирская область', 'Орловская область', 'Костромская область', 'Еврейская АО', 'Челябинская область', 'Оренбургская область', 'Амурская область', 'Архангельская область', 'Московская область', 'Горный Алтай', 'Дагестан', 'Нижегородская область', 'Агинский Бурятский АО', 'Красноярский край', 'Тульская область', 'Белгородская область', 'Кабардино-Балкария', 'Ярославская область', 'Псковская область', 'Тюменская область', 'Иркутская область', 'Самарская область', 'Владимирская область', 'Удмуртия', 'Саратовская область', 'Воронежская область', 'Смоленская область', 'Хабаровский край', 'Сахалинская область', 'Коми', 'Ставропольский край', 'Калужская область', 'Адыгея', 'Чувашия', 'Новгородская область', 'Свердловская область', 'Ивановская область', 'Северная Осетия', 'Эвенкийский АО', 'Рязанская область', 'Томская область', 'Тамбовская область', 'Санкт-Петербург', 'Краснодарский край', 'Приморский край', 'Ленинградская область', 'Кировская область', 'Курская область', 'Камчатская область', 'Липецкая область', 'Башкирия', 'Бурятия', 'Кемеровская область', 'Карачаево-Черкесия', 'Якутия', 'Читинская область', 'Москва', 'Усть-Ордынский Бурятский АО', 'Мурманская область', 'Тверская область', 'Пермская область', 'Карелия', 'Ульяновская область', 'Магаданская область', 'Ямало-Ненецкий АО', 'Омская область'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Ханты-Мансийский АО', 'Брянская область', 'Татарстан', 'Мордовская республика', 'Волгоградская область', 'Ростовская область', 'Калмыкия', 'Калининградская область', 'Вологодская область', 'Астраханская область', 'Хакасия', 'Пензенская область', 'Алтайский край', 'Курганская область', 'Марийская республика', 'Новосибирская область', 'Орловская область', 'Костромская область', 'Еврейская АО', 'Челябинская область', 'Оренбургская область', 'Амурская область', 'Архангельская область', 'Московская область', 'Горный Алтай', 'Агинский Бурятский АО', 'Нижегородская область', 'Дагестан', 'Красноярский край', 'Тульская область', 'Белгородская область', 'Кабардино-Балкария', 'Ярославская область', 'Псковская область', 'Тюменская область', 'Иркутская область', 'Самарская область', 'Владимирская область', 'Удмуртия', 'Саратовская область', 'Воронежская область', 'Смоленская область', 'Хабаровский край', 'Сахалинская область', 'Коми', 'Ставропольский край', 'Калужская область', 'Адыгея', 'Чувашия', 'Новгородская область', 'Свердловская область', 'Ивановская область', 'Эвенкийский АО', 'Северная Осетия', 'Рязанская область', 'Томская область', 'Тамбовская область', 'Санкт-Петербург', 'Краснодарский край', 'Приморский край', 'Ленинградская область', 'Кировская область', 'Курская область', 'Камчатская область', 'Липецкая область', 'Башкирия', 'Бурятия', 'Кемеровская область', 'Карачаево-Черкесия', 'Якутия', 'Читинская область', 'Москва', 'Усть-Ордынский Бурятский АО', 'Мурманская область', 'Тверская область', 'Пермская область', 'Карелия', 'Ульяновская область', 'Магаданская область', 'Ямало-Ненецкий АО', 'Омская область'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Ханты-Мансийский АО', 'Брянская область', 'Татарстан', 'Мордовская республика', 'Волгоградская область', 'Ростовская область', 'Калмыкия', 'Калининградская область', 'Вологодская область', 'Астраханская область', 'Хакасия', 'Пензенская область', 'Алтайский край', 'Курганская область', 'Марийская республика', 'Новосибирская область', 'Орловская область', 'Костромская область', 'Еврейская АО', 'Челябинская область', 'Оренбургская область', 'Амурская область', 'Архангельская область', 'Московская область', 'Горный Алтай', 'Агинский Бурятский АО', 'Нижегородская область', 'Красноярский край', 'Тульская область', 'Белгородская область', 'Кабардино-Балкария', 'Ярославская область', 'Псковская область', 'Тюменская область', 'Иркутская область', 'Самарская область', 'Владимирская область', 'Удмуртия', 'Саратовская область', 'Воронежская область', 'Смоленская область', 'Хабаровский край', 'Сахалинская область', 'Коми', 'Ставропольский край', 'Калужская область', 'Адыгея', 'Чувашия', 'Новгородская область', 'Свердловская область', 'Ивановская область', 'Эвенкийский АО', 'Северная Осетия', 'Рязанская область', 'Томская область', 'Тамбовская область', 'Санкт-Петербург', 'Краснодарский край', 'Приморский край', 'Ленинградская область', 'Кировская область', 'Курская область', 'Камчатская область', 'Липецкая область', 'Башкирия', 'Бурятия', 'Кемеровская область', 'Карачаево-Черкесия', 'Якутия', 'Читинская область', 'Москва', 'Усть-Ордынский Бурятский АО', 'Мурманская область', 'Тверская область', 'Пермская область', 'Карелия', 'Ульяновская область', 'Магаданская область', 'Ямало-Ненецкий АО', 'Омская область'}
#
#
# ==========
# TP_PROVINCE
# {nan, 'Ханты-Мансийский АО', 'Брянская область', 'Татарстан', 'Мордовская республика', 'Волгоградская область', 'Ростовская область', 'Калининградская область', 'Вологодская область', 'Астраханская область', 'Пензенская область', 'Курганская область', 'Алтайский край', 'Марийская республика', 'Новосибирская область', 'Орловская область', 'Костромская область', 'Еврейская АО', 'Челябинская область', 'Оренбургская область', 'Амурская область', 'Архангельская область', 'Горный Алтай', 'Нижегородская область', 'Красноярский край', 'Тульская область', 'Белгородская область', 'Кабардино-Балкария', 'Ярославская область', 'Псковская область', 'Тюменская область', 'Иркутская область', 'Самарская область', 'Владимирская область', 'Удмуртия', 'Саратовская область', 'Воронежская область', 'Смоленская область', 'Хабаровский край', 'Сахалинская область', 'Коми', 'Ставропольский край', 'Калужская область', 'Адыгея', 'Чувашия', 'Новгородская область', 'Свердловская область', 'Ивановская область', 'Рязанская область', 'Томская область', 'Тамбовская область', 'Санкт-Петербург', 'Краснодарский край', 'Приморский край', 'Кировская область', 'Курская область', 'Камчатская область', 'Липецкая область', 'Башкирия', 'Бурятия', 'Кемеровская область', 'Якутия', 'Читинская область', 'Москва', 'Мурманская область', 'Тверская область', 'Пермская область', 'Карелия', 'Ульяновская область', 'Магаданская область', 'Омская область'}
#
#
# ==========
# REGION_NM
# {nan, 'СЕВЕРО-ЗАПАДНЫЙ', '
4620', '1909,16', '1200', '1230', '1819,09', '1095,89', '904,08', '578,06', '1470', '224,59', '3960', '2700', '648,68', '1770', '2540', '991,19', '2002,45', '816,83', '4320', '2470', '3780,1', '1110,39', '2200', '682', '4446,3', '599,19', '846,55', '2629,87', '1259,39', '1141,06', '2699,88', '1160,96', '2642,83', '1959,99', '1599,9', '3070', '1090', '2201,11', '9060', '1550', '954,34', '5550', '1478,49', '339,83', '1780', '4490', '1145,85', '1296,4', '2060', '3570', '1930', '981,71', '989,15', '1697,22', ...
#
#
# ==========
# sample
# {'train'}

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
# Out:
# 0         7000.0
# 1         4100.0
# 2        40000.0
# 3        20000.0
# 4        17000.0
# 5         7000.0
# 6        10000.0
# 7         7500.0
# 8         9000.0
# 9         4000.0
# 10       15000.0
# 11       12000.0
# 12        8000.0
# 13       20000.0
# 14       18500.0
# 15       14000.0
# 16        6000.0
# 17        9000.0
# 18        5000.0
# 19       15000.0
# 20        6100.0
# 21       22180.0
# 22        9000.0
# 23        8700.0
# 24        7000.0
# 25        6000.0
# 26       15000.0
# 27       12000.0
# 28       11000.0
# 29        8000.0
#           ...
# 30103    12000.0
# 30104    10000.0
# 30105    10000.0
# 30106     8000.0
# 30107    11000.0
# 30108     7000.0
# 30109    10000.0
# 30110     8000.0
# 30111    25000.0
# 30112    10000.0
# 30113    12000.0
# 30114     7000.0
# 30115    12000.0
# 30116    14500.0
# 30117    12000.0
# 30118     8000.0
# 30119     7000.0
# 30120    10000.0
# 30121    10000.0
# 30122    10000.0
# 30123    15000.0
# 30124     8100.0
# 30125     9500.0
# 30126    13000.0
# 30127    10000.0
# 30128    12000.0
# 30129    10000.0
# 30130     6000.0
# 30131     4500.0
# 30132    20000.0
# Name: PERSONAL_INCOME, Length: 30133, dtype: float64

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Что с ними сделать?
#
# (единственного верного ответа нет - аргументируйте)

# %%
nans = lambda df: df[df.isnull().T.any()]
df_tmp = nans(df.drop('PREVIOUS_CARD_NUM_UTILIZED',1).drop('TP_PROVINCE',1))
df_tmp[['GEN_INDUSTRY','GEN_TITLE','ORG_TP_STATE','ORG_TP_FCAPITAL','JOB_DIR','REGION_NM','WORK_TIME']]
# Out:
#       GEN_INDUSTRY GEN_TITLE ORG_TP_STATE ORG_TP_FCAPITAL JOB_DIR  \
# 1              NaN       NaN          NaN             NaN     NaN
# 5              NaN       NaN          NaN             NaN     NaN
# 8              NaN       NaN          NaN             NaN     NaN
# 12             NaN       NaN          NaN             NaN     NaN
# 20             NaN       NaN          NaN             NaN     NaN
# 28             NaN       NaN          NaN             NaN     NaN
# 30             NaN       NaN          NaN             NaN     NaN
# 57             NaN       NaN          NaN             NaN     NaN
# 77             NaN       NaN          NaN             NaN     NaN
# 96             NaN       NaN          NaN             NaN     NaN
# 103            NaN       NaN          NaN             NaN     NaN
# 111            NaN       NaN          NaN             NaN     NaN
# 156            NaN       NaN          NaN             NaN     NaN
# 177            NaN       NaN          NaN             NaN     NaN
# 192            NaN       NaN          NaN             NaN     NaN
# 194            NaN       NaN          NaN             NaN     NaN
# 202            NaN       NaN          NaN             NaN     NaN
# 203            NaN       NaN          NaN             NaN     NaN
# 204            NaN       NaN          NaN             NaN     NaN
# 211            NaN       NaN          NaN             NaN     NaN
# 214            NaN       NaN          NaN             NaN     NaN
# 246            NaN       NaN          NaN             NaN     NaN
# 247            NaN       NaN          NaN             NaN     NaN
# 252            NaN       NaN          NaN             NaN     NaN
# 254            NaN       NaN          NaN             NaN     NaN
# 280            NaN       NaN          NaN             NaN     NaN
# 293            NaN       NaN          NaN             NaN     NaN
# 300            NaN       NaN          NaN             NaN     NaN
# 314            NaN       NaN          NaN             NaN     NaN
# 325            NaN       NaN          NaN             NaN     NaN
# ...            ...       ...          ...             ...     ...
# 29818          NaN       NaN          NaN             NaN     NaN
# 29853          NaN       NaN          NaN             NaN     NaN
# 29937          NaN       NaN          NaN             NaN     NaN
# 29941          NaN       NaN          NaN             NaN     NaN
# 29944          NaN       NaN          NaN             NaN     NaN
# 29978          NaN       NaN          NaN             NaN     NaN
# 29983          NaN       NaN          NaN             NaN     NaN
# 29997          NaN       NaN          NaN             NaN     NaN
# 29999          NaN       NaN          NaN             NaN     NaN
# 30010          NaN       NaN          NaN             NaN     NaN
# 30024          NaN       NaN          NaN             NaN     NaN
# 30029          NaN       NaN          NaN             NaN     NaN
# 30043          NaN       NaN          NaN             NaN     NaN
# 30061          NaN       NaN          NaN             NaN     NaN
# 30062          NaN       NaN          NaN             NaN     NaN
# 30070          NaN       NaN          NaN             NaN     NaN
# 30072          NaN       NaN          NaN             NaN     NaN
# 30074          NaN       NaN          NaN             NaN     NaN
# 30076          NaN       NaN          NaN             NaN     NaN
# 30077          NaN       NaN          NaN             NaN     NaN
# 30082          NaN       NaN          NaN             NaN     NaN
# 30085          NaN       NaN          NaN             NaN     NaN
# 30087          NaN       NaN          NaN             NaN     NaN
# 30088          NaN       NaN          NaN             NaN     NaN
# 30091          NaN       NaN          NaN             NaN     NaN
# 30095          NaN       NaN          NaN             NaN     NaN
# 30101          NaN       NaN          NaN             NaN     NaN
# 30106          NaN       NaN          NaN             NaN     NaN
# 30107          NaN       NaN          NaN             NaN     NaN
# 30131          NaN       NaN          NaN             NaN     NaN
#
#                 REGION_NM  WORK_TIME
# 1           ЦЕНТРАЛЬНЫЙ 1        NaN
# 5             ПРИВОЛЖСКИЙ        NaN
# 8       ЗАПАДНО-СИБИРСКИЙ        NaN
# 12      ЗАПАДНО-СИБИРСКИЙ        NaN
# 20              УРАЛЬСКИЙ        NaN
# 28          ЦЕНТРАЛЬНЫЙ 2        NaN
# 30          ЦЕНТРАЛЬНЫЙ 1        NaN
# 57          ЦЕНТРАЛЬНЫЙ 1        NaN
# 77          ЦЕНТРАЛЬНЫЙ 2        NaN
# 96             ПОВОЛЖСКИЙ        NaN
# 103       СЕВЕРО-ЗАПАДНЫЙ        NaN
# 111       СЕВЕРО-ЗАПАДНЫЙ        NaN
# 156            ПОВОЛЖСКИЙ        NaN
# 177           ПРИВОЛЖСКИЙ        NaN
# 192       ДАЛЬНЕВОСТОЧНЫЙ        NaN
# 194         ЦЕНТРАЛЬНЫЙ 2        NaN
# 202             УРАЛЬСКИЙ        NaN
# 203                 ЮЖНЫЙ        NaN
# 204           ПРИВОЛЖСКИЙ        NaN
# 211     ЗАПАДНО-СИБИРСКИЙ        NaN
# 214         ЦЕНТРАЛЬНЫЙ 2        NaN
# 246         ЦЕНТРАЛЬНЫЙ 2        NaN
# 247           ПРИВОЛЖСКИЙ        NaN
# 252            ПОВОЛЖСКИЙ        NaN
# 254             УРАЛЬСКИЙ        NaN
# 280       ДАЛЬНЕВОСТОЧНЫЙ        NaN
# 293                 ЮЖНЫЙ        NaN
# 300                 ЮЖНЫЙ        NaN
# 314         ЦЕНТРАЛЬНЫЙ 2        NaN
# 325                 ЮЖНЫЙ        NaN
# ...                   ...        ...
# 29818     ДАЛЬНЕВОСТОЧНЫЙ        NaN
# 29853     СЕВЕРО-ЗАПАДНЫЙ        NaN
# 29937           УРАЛЬСКИЙ        NaN
# 29941     ДАЛЬНЕВОСТОЧНЫЙ        NaN
# 29944               ЮЖНЫЙ        NaN
# 29978               ЮЖНЫЙ        NaN
# 29983               ЮЖНЫЙ        NaN
# 29997               ЮЖНЫЙ        NaN
# 29999       ЦЕНТРАЛЬНЫЙ 2        NaN
# 30010               ЮЖНЫЙ        NaN
# 30024       ЦЕНТРАЛЬНЫЙ 2        NaN
# 30029          ПОВОЛЖСКИЙ        NaN
# 30043       ЦЕНТРАЛЬНЫЙ 2        NaN
# 30061   ЗАПАДНО-СИБИРСКИЙ        NaN
# 30062   ЗАПАДНО-СИБИРСКИЙ        NaN
# 30070         ПРИВОЛЖСКИЙ        NaN
# 30072       ЦЕНТРАЛЬНЫЙ 1        NaN
# 30074  ВОСТОЧНО-СИБИРСКИЙ        NaN
# 30076       ЦЕНТРАЛЬНЫЙ 2        NaN
# 30077          ПОВОЛЖСКИЙ        NaN
# 30082               ЮЖНЫЙ        NaN
# 30085               ЮЖНЫЙ        NaN
# 30087   ЗАПАДНО-СИБИРСКИЙ        NaN
# 30088         ПРИВОЛЖСКИЙ        NaN
# 30091     СЕВЕРО-ЗАПАДНЫЙ        NaN
# 30095       ЦЕНТРАЛЬНЫЙ 1        NaN
# 30101       ЦЕНТРАЛЬНЫЙ 1        NaN
# 30106       ЦЕНТРАЛЬНЫЙ 1        NaN
# 30107          ПОВОЛЖСКИЙ        NaN
# 30131     ДАЛЬНЕВОСТОЧНЫЙ        NaN
#
# [2719 rows x 7 columns]

# %% [raw]
# GEN_INDUSTRY, GEN_TITLE, ORG_TP_STATE, ORG_TP_FCAPITAL, JOB_DIR, REGION_NM, WORK_TIME,TP_PROVINCE
# строки с пропусками в этих данных я бы удалил в связи с тем, что они все взаимосвязаны и у таких записей отсутвуют важные поля
# ---updated----
# после неколько раз запущенной модели получилось, что лучше просто заполнить все пропуски ''
#
#
#
# пропуски в PREVIOUS_CARD_NUM_UTILIZED не пропуски, а нули

# %% [markdown]
# #### Задание 2. Есть ли категориальные признаки? Что с ними делать?

# %% [raw]
# EDUCATION
# MARITAL_STATUS
# GEN_INDUSTRY
# GEN_TITLE
# ORG_TP_STATE
# ORG_TP_FCAPITAL
# JOB_DIR
# FAMILY_INCOME
# REG_ADDRESS_PROVINCE
# FACT_ADDRESS_PROVINCE
# POSTAL_ADDRESS_PROVINCE
# TP_PROVINCE
# REGION_NM
# категориальные данные, которые необходимо перевети в бинарные значения в зависимости от категории

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками
# * Кодировала категориальные признаки
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
def preproc_data(df_input):
    df_output = df_input.copy()
    ## Your Code Here
    
    df_output = df_output.drop('AGREEMENT_RK',1)
    
    #df_output = df_output[~df['GEN_TITLE'].isnull()&~df['WORK_TIME'].\
    #                      isnull()&~df['REGION_NM'].isnull()&~df['TP_PROVINCE'].isnull()]
    
    df_output['PREVIOUS_CARD_NUM_UTILIZED'] = df_output['PREVIOUS_CARD_NUM_UTILIZED'].fillna(0)
    df_output= df_output.fillna('')
    
    sep_rep = lambda x: x.replace(',', '.')
    for i in ['PERSONAL_INCOME', 'CREDIT', 'FST_PAYMENT', 'LOAN_AVG_DLQ_AMT', 'LOAN_MAX_DLQ_AMT']:
        df_output[i] = df_output[i].map(sep_rep).astype('float')
    
    for i in df_output.columns: # перебираем все столбцы
        if str(df_output[i].dtype) == 'object' and i  != 'sample':
            df_tmp = pd.get_dummies(df_output[i])
            df_output = df_output.join(pd.get_dummies(df_tmp), lsuffix='_df_output', rsuffix='_df_tmp')
            df_output = df_output.drop(i,1)    
            
            
    return df_output

# %%
df_preproc = df.pipe(preproc_data)

df_train_preproc = df_preproc.query('sample == "train"').drop(['sample'], axis=1)
df_test_preproc = df_preproc.query('sample == "test"').drop(['sample'], axis=1)

# %% [markdown]
# #### Задание 4. Отделите целевую переменную и остальные признаки
#
# Должно получится:
# * 2 матрицы: X и X_test
# * 2 вектора: y и y_test

# %%
y = df_train_preproc['TARGET']
df_train_preproc = df_train_preproc.drop('TARGET',1)

# %%
from sklearn.cross_validation import train_test_split
# test_size=0.3, random_state=42

## Your Code Here
X, X_test, y, y_test = train_test_split(df_train_preproc, y, test_size=0.3, random_state=42)

# %% [markdown]
# #### Задание 5. Обучение и оценка качества разных моделей

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
# Постепенно мы узнаем, что они делают а сейчас учимся понимать какой работает качественнее
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

## Your Code Here
predict = []
predict_proba = []

model = DecisionTreeClassifier()
model.fit(X, y)
predict.append(model.predict(X_test))
predict_proba.append(model.predict_proba(X_test))

model = RandomForestClassifier()
model.fit(X, y)
predict.append(model.predict(X_test))
predict_proba.append(model.predict_proba(X_test))

model = LogisticRegression()
model.fit(X, y)
predict.append(model.predict(X_test))
predict_proba.append(model.predict_proba(X_test))

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report

## Your Code Here
metrics = []
for i in predict:
    metrics.append([accuracy_score(y_test, i),precision_score(y_test, i),recall_score(y_test,i)])
metrics
# Out:
# [[0.8022772060433545, 0.15748031496062992, 0.14414414414414414],
#  [0.8780380994088023, 0.3333333333333333, 0.0036036036036036037],
#  [0.8780380994088023, 0.3333333333333333, 0.0036036036036036037]]

# %%
for i in predict:
    print(classification_report(y_test, i))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.88      0.89      0.89      4012
#           1       0.16      0.14      0.15       555
#
# avg / total       0.79      0.80      0.80      4567
#
#              precision    recall  f1-score   support
#
#           0       0.88      1.00      0.94      4012
#           1       0.33      0.00      0.01       555
#
# avg / total       0.81      0.88      0.82      4567
#
#              precision    recall  f1-score   support
#
#           0       0.88      1.00      0.94      4012
#           1       0.33      0.00      0.01       555
#
# avg / total       0.81      0.88      0.82      4567

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально сравнить)
# Возможно вас удивит качество! Но задача подобрана специально ;) Такое качество тоже бывает

## Your Code Here
data = {
        'name': ['accuracy_score','precision_score','recall_score'],\
        'DTC' : metrics[0],\
        'RFC' : metrics[1],\
        'LG' : metrics[2]
        }       
data 
df_temp = pd.DataFrame.from_dict(data)
df_temp.plot.bar();

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе
# Подпишите оси и линии

## Your Code Here
# %matplotlib inline
from matplotlib import pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve


fpr0, tpr0, thresholds0 = roc_curve(y_test, predict_proba[0][:,1])
fpr1, tpr1, thresholds1 = roc_curve(y_test, predict_proba[1][:,1])
fpr2, tpr2, thresholds2 = roc_curve(y_test, predict_proba[2][:,1])
plt.figure(figsize=(5, 5))
line1, = plt.plot(fpr0, tpr0,'go-',label='DTC', linewidth=4)
line2, = plt.plot(fpr1, tpr1,label='RFS', linewidth=2)
line3, = plt.plot(fpr2, tpr2,label='LG', linewidth=2)
plt.plot([0, 1], [0, 1])
plt.ylabel('tpr')
plt.xlabel('fpr')
plt.grid(True)
plt.title('ROC curve')
plt.xlim((-0.02, 1.02))
plt.ylim((-0.02, 1.02))
plt.legend(handles=[line1, line2,line3])

for i in predict_proba:
    print(roc_auc_score(y_test, i[:,1]))
# Out:
# 0.5187320920122516
# 0.6077441100123054
# 0.6381320003952108

# %%
from sklearn.cross_validation import cross_val_score
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc


df_preproc = df.pipe(preproc_data)

df_train_preproc = df_preproc.query('sample == "train"').drop(['sample'], axis=1)
df_test_preproc = df_preproc.query('sample == "test"').drop(['sample'], axis=1)

y = df_train_preproc['TARGET']
df_train_preproc = df_train_preproc.drop('TARGET',1)

print(cross_val_score(
    DecisionTreeClassifier(),
    df_train_preproc,
    y,
    scoring='roc_auc',
    cv=10
).mean())

print(cross_val_score(
    RandomForestClassifier(),
    df_train_preproc,
    y,
    scoring='roc_auc',
    cv=10
).mean())

print(cross_val_score(
    LogisticRegression(),
    df_train_preproc,
    y,
    scoring='roc_auc',
    cv=10
).mean())


## Your Code Here
# Out:
# 0.5342590735836715
# 0.594720231450913
# 0.6372331001067912

# %%
# Взять лучшую модель и сделать предсказания (с вероятностями (!!!)) для test выборки

#predict = 
## Your Code Here

df_preproc = df.pipe(preproc_data)

df_train_preproc = df_preproc.query('sample == "train"').drop(['sample'], axis=1)
df_test_preproc = df_preproc.query('sample == "test"').drop(['sample'], axis=1)

X, X_test, y, y_test = train_test_split(df_train_preproc, y, test_size=0.3, random_state=42)

model = LogisticRegression()
model.fit(X, y)
predict = model.predict(df_test_preproc)
predict_proba = model.predict_proba(df_test_preproc)

# %%
# Померить roc_auc на тесте
# Вывести текстом и на графике =)

## Your Code Here

predict = model.predict(X_test)
predict_proba = model.predict_proba(X_test)

roc_auc_score_val = roc_auc_score(y_test, predict_proba[:,1])
fpr0, tpr0, thresholds0 = roc_curve(y_test, predict_proba[:,1])
plt.figure(figsize=(5, 5))
line1, = plt.plot(fpr0, tpr0,'go-',label='roc_auc={}'.format(roc_auc_score_val), linewidth=4)
plt.plot([0, 1], [0, 1])
plt.ylabel('tpr')
plt.xlabel('fpr')
plt.grid(True)
plt.title('ROC curve')
plt.xlim((-0.02, 1.02))
plt.ylim((-0.02, 1.02))
plt.legend(handles=[line1])
print(roc_auc_score_val)
# Out:
# 0.6401197308973978

# %% [markdown]
# ### Больше обязательных заданий нет, но ниже вы можете провести исследование, поиграться с данными
# ### Это возможность написать код, который я посмотрю и в случае чего откомметирую. ;)
# ### Это не оценивается и остается на ваше усмотрение. Просто дополнительная возможность

# %% [raw]
# ### И далее ;)
#
# к сожалению на этой неделе у меня нет времени(
# надеюсь на подобные задания в будущем!
# спасибо за возможность
